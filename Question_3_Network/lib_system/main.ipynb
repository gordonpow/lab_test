# %%
# !python -u manage.py scrape_books "愛情"
# Out:
# 正在搜尋關鍵字: 愛情 ...
# 已將網頁內容存為 debug_books.html，若無資料請檢查此檔案。
# 成功新增: 因你綻放的戀愛情感 全 (作者: 未知作者)
# 成功新增: 當愛情心滿意足 全 (作者: 未知作者)
# 成功新增: 愛情往返3(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 愛情往返2(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 愛情往返2【限量特裝版・贈戀人甜蜜依偎立牌】(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 當愛情從天而降 全 (作者: 未知作者)
# 成功新增: 愛情往返1(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 愛情往返3【限量特裝版.附贈A4海報】(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 愛情往返1【限量特裝版・首集隨機費洛蒙香氛片】(韓國網漫百萬人氣ABO作，無聖光火辣開車!) (作者: 未知作者)
# 成功新增: 在樂園裡墮入愛情 全 (作者: 未知作者)
# 爬蟲結束，共新增 10 本書。

# %% [markdown]
# 爬蟲書資料集 "關鍵字"

# %%
# !cd .\lib_system\

# %%
# !python -u manage.py runserver
